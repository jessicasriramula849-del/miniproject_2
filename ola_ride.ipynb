# %%
OLA RIDE INSIGHTS - JESSICA SRIRAMULA - MINIPROJECT 2
# Out:
#   Cell In[28], line 1
#     OLA RIDE INSIGHTS - JESSICA SRIRAMULA - MINIPROJECT 2
#         ^
# SyntaxError: invalid syntax

# %%
Step 1: reading the excel file dataset provided

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

js = pd.read_excel(r'C:\Users\pc\Desktop\miniproject2\OLA_dataset.xlsx')
print(js)
# Out:
#                       Date      Time     Booking_ID        Booking_Status  \
# 0      2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1      2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2      2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3      2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4      2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
# ...                    ...       ...            ...                   ...
# 103019 2024-07-31 09:06:00  09:06:00  CNR9488489435               Success
# 103020 2024-07-31 15:12:00  15:12:00  CNR3151743100               Success
# 103021 2024-07-31 13:59:00  13:59:00  CNR1286151233               Success
# 103022 2024-07-31 14:56:00  14:56:00  CNR2027162035               Success
# 103023 2024-07-31 13:57:00  13:57:00  CNR9770709721               Success
#
#        Customer_ID Vehicle_Type    Pickup_Location  Drop_Location  V_TAT  \
# ...

# %%
js.head()
# Out:
#                  Date      Time     Booking_ID        Booking_Status  \
# 0 2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1 2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2 2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3 2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4 2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  \
# 0   CID713523  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN
# 1   CID225428         Bike     Magadi Road       Varthur  203.0   30.0
# 2   CID270156    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0
# 3   CID581320        eBike      HSR Layout   Vijayanagar    NaN    NaN
# 4   CID939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0
#
#                      Canceled_Rides_by_Customer      Canceled_Rides_by_Driver  \
# ...

# %%
js.tail()
# Out:
#                       Date      Time     Booking_ID Booking_Status  \
# 103019 2024-07-31 09:06:00  09:06:00  CNR9488489435        Success
# 103020 2024-07-31 15:12:00  15:12:00  CNR3151743100        Success
# 103021 2024-07-31 13:59:00  13:59:00  CNR1286151233        Success
# 103022 2024-07-31 14:56:00  14:56:00  CNR2027162035        Success
# 103023 2024-07-31 13:57:00  13:57:00  CNR9770709721        Success
#
#        Customer_ID Vehicle_Type    Pickup_Location  Drop_Location  V_TAT  \
# 103019   CID371654   Prime Plus      Richmond Town        Varthur  245.0
# 103020   CID334158         Auto        Vijayanagar  Richmond Town   84.0
# 103021   CID113188    Prime SUV  Bannerghatta Road       JP Nagar   35.0
# 103022   CID118301        eBike        Indiranagar    Magadi Road  210.0
# 103023   CID217959         Auto             Ulsoor         Hennur  175.0
#
#         C_TAT Canceled_Rides_by_Customer Canceled_Rides_by_Driver  \
# ...

# %%
Step 2: performing EDA on the excel dataset to handle missing(null) values and checking for data consistency and feature engineering.

# %%
js.describe()
# Out:
#                              Date         V_TAT         C_TAT  Booking_Value  \
# count                      103024  63967.000000  63967.000000  103024.000000
# mean   2024-07-16 11:31:38.879678    170.876952     84.873372     548.751883
# min           2024-07-01 00:00:00     35.000000     25.000000     100.000000
# 25%           2024-07-08 18:41:00     98.000000     55.000000     242.000000
# 50%           2024-07-16 11:23:00    168.000000     85.000000     386.000000
# 75%           2024-07-24 05:18:00    238.000000    115.000000     621.000000
# max           2024-07-31 23:58:00    308.000000    145.000000    2999.000000
# std                           NaN     80.803640     36.005100     536.541221
#
#        Ride_Distance  Driver_Ratings  Customer_Rating  Vehicle Images
# count  103024.000000    63967.000000     63967.000000             0.0
# mean       14.189927        3.997457         3.998313             NaN
# ...

# %%
Step 3: checking datatypes for each column

# %%
js.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Date                        103024 non-null  datetime64[us]
#  1   Time                        103024 non-null  object
#  2   Booking_ID                  103024 non-null  str
#  3   Booking_Status              103024 non-null  str
#  4   Customer_ID                 103024 non-null  str
#  5   Vehicle_Type                103024 non-null  str
#  6   Pickup_Location             103024 non-null  str
#  7   Drop_Location               103024 non-null  str
#  8   V_TAT                       63967 non-null   float64
#  9   C_TAT                       63967 non-null   float64
#  10  Canceled_Rides_by_Customer  10499 non-null   str
#  11  Canceled_Rides_by_Driver    18434 non-null   str
#  12  Incomplete_Rides            63967 non-null   str
# ...

# %%
Step4: making sure each colum is the correct datatype, here only the time column datatype has to be changed into datetime datatype, 
everything else is fine.

# %%
Step 5: checking the total number of null values in each colum of the dataset

# %%
js.isnull().sum()
# Out:
# Date                               0
# Time                               0
# Booking_ID                         0
# Booking_Status                     0
# Customer_ID                        0
# Vehicle_Type                       0
# Pickup_Location                    0
# Drop_Location                      0
# V_TAT                          39057
# C_TAT                          39057
# Canceled_Rides_by_Customer     92525
# Canceled_Rides_by_Driver       84590
# Incomplete_Rides               39057
# Incomplete_Rides_Reason        99098
# Booking_Value                      0
# Payment_Method                 39057
# Ride_Distance                      0
# Driver_Ratings                 39057
# Customer_Rating                39057
# Vehicle Images                103024
# dtype: int64

# %%
Step 6: then calculating the percentage of null values in each column

# %%
import pandas as pd

missing_percentage = (js.isnull().sum() / js.shape[0]) * 100

print(missing_percentage)
# Out:
# Date                            0.000000
# Time                            0.000000
# Booking_ID                      0.000000
# Booking_Status                  0.000000
# Customer_ID                     0.000000
# Vehicle_Type                    0.000000
# Pickup_Location                 0.000000
# Drop_Location                   0.000000
# V_TAT                          37.910584
# C_TAT                          37.910584
# Canceled_Rides_by_Customer     89.809171
# Canceled_Rides_by_Driver       82.107082
# Incomplete_Rides               37.910584
# Incomplete_Rides_Reason        96.189237
# Booking_Value                   0.000000
# Payment_Method                 37.910584
# Ride_Distance                   0.000000
# Driver_Ratings                 37.910584
# Customer_Rating                37.910584
# Vehicle Images                100.000000
# dtype: float64

# %%
Step 7: replacing all the null values of numerical and text colums with a constant '0' value for the analysis(because deleting all the rows with null values will delete necessary info) and deleting the Vtat and Ctat colums as they are not necessary for this analysis.

# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\pc\Desktop\miniproject2\OLA_dataset.xlsx")

df = df.fillna({
    'Canceled_Rides_by_Customer': "0",
    'Canceled_Rides_by_Driver': "0",
    'Incomplete_Rides': "0",
    'Incomplete_Rides_Reason': "No Reason Provided",
    'Payment_Method': "Not Specified"
})

df = df.fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                          0
# Time                          0
# Booking_ID                    0
# Booking_Status                0
# Customer_ID                   0
# Vehicle_Type                  0
# Pickup_Location               0
# Drop_Location                 0
# V_TAT                         0
# C_TAT                         0
# Canceled_Rides_by_Customer    0
# Canceled_Rides_by_Driver      0
# Incomplete_Rides              0
# Incomplete_Rides_Reason       0
# Booking_Value                 0
# Payment_Method                0
# Ride_Distance                 0
# Driver_Ratings                0
# Customer_Rating               0
# Vehicle Images                0
# dtype: int64

# %%
import os
import pandas as pd

df = pd.read_excel(r'C:\Users\pc\Desktop\miniproject2\OLA_dataset.xlsx')

desktop_path = os.path.join(os.path.expanduser("~"), "Desktop")
save_file_path = os.path.join(desktop_path, "Cleaned_OLA_Dataset.xlsx")

df_clean = df.to_excel(save_file_path, index=False)
print("File successfully saved to Desktop!")
# Out:
# File successfully saved to Desktop!

# %%
print(df['Canceled_Rides_by_Customer'].head())
# Out:
# 0                                               0
# 1                                               0
# 2                                               0
# 3    Driver is not moving towards pickup location
# 4                                               0
# Name: Canceled_Rides_by_Customer, dtype: str

# %%
print(df['Canceled_Rides_by_Driver'].head())
# Out:
# 0    Personal & Car related issue
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# Name: Canceled_Rides_by_Driver, dtype: str

# %%
print(df['Incomplete_Rides'].head())
# Out:
# 0     0
# 1    No
# 2    No
# 3     0
# 4    No
# Name: Incomplete_Rides, dtype: str

# %%
print(df['Incomplete_Rides_Reason'].head())
# Out:
# 0    No Reason Provided
# 1    No Reason Provided
# 2    No Reason Provided
# 3    No Reason Provided
# 4    No Reason Provided
# Name: Incomplete_Rides_Reason, dtype: str

# %%
print(df['Payment_Method'])
# Out:
# 0         Not Specified
# 1                  Cash
# 2                   UPI
# 3         Not Specified
# 4           Credit Card
#               ...
# 103019             Cash
# 103020              UPI
# 103021             Cash
# 103022              UPI
# 103023              UPI
# Name: Payment_Method, Length: 103024, dtype: str

# %%
Replacing the null values in driver ratings and customer ratings with a constant '0' value to help in this analysis.

# %%
df['Driver_Ratings'] = df['Driver_Ratings'].fillna(0, inplace=True)
print(df['Driver_Ratings'].head())
# Out:
# 0    0.0
# 1    4.1
# 2    4.2
# 3    0.0
# 4    4.0
# Name: Driver_Ratings, dtype: float64
# C:\Users\pc\AppData\Local\Temp\ipykernel_27372\2140051763.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Driver_Ratings'] = df['Driver_Ratings'].fillna(0, inplace=True)

# %%
df['Customer_Rating'] = df['Customer_Rating'].fillna(0, inplace= True)
print(df['Customer_Rating'].head())
# Out:
# 0    0.0
# 1    4.0
# 2    4.8
# 3    0.0
# 4    3.0
# Name: Customer_Rating, dtype: float64
# C:\Users\pc\AppData\Local\Temp\ipykernel_27372\2554471124.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Customer_Rating'] = df['Customer_Rating'].fillna(0, inplace= True)

# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\pc\Desktop\miniproject2\OLA_dataset.xlsx")

columns_to_remove = ['V_TAT', 'C_TAT']
df_cleaned = df.drop(columns_to_remove, axis=1)

# %%
import pandas as pd

fg = pd.read_excel(r"C:\Users\pc\Desktop\miniproject2\OLA_dataset.xlsx")

fg_cleaned = fg.drop(columns=["Vehicle Images"])

# %%
print(fg_cleaned)

fg_cleaned.to_excel('OLA_dataset jessica.xlsx', index=False, sheet_name='CleanedData')
# Out:
#                       Date      Time     Booking_ID        Booking_Status  \
# 0      2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1      2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2      2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3      2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4      2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
# ...                    ...       ...            ...                   ...
# 103019 2024-07-31 09:06:00  09:06:00  CNR9488489435               Success
# 103020 2024-07-31 15:12:00  15:12:00  CNR3151743100               Success
# 103021 2024-07-31 13:59:00  13:59:00  CNR1286151233               Success
# 103022 2024-07-31 14:56:00  14:56:00  CNR2027162035               Success
# 103023 2024-07-31 13:57:00  13:57:00  CNR9770709721               Success
#
#        Customer_ID Vehicle_Type    Pickup_Location  Drop_Location  V_TAT  \
# ...

# %%
Step 8: checking total number of rows and colums we have.

# %%
import pandas as pd

js = pd.read_excel(r'C:\Users\pc\Desktop\miniproject2\OLA_dataset.xlsx')
print(js.shape)
# Out:
# (103024, 20)

# %%
Step 9: checking each column name.

# %%
print(js.columns)
# Out:
# Index(['Date', 'Time', 'Booking_ID', 'Booking_Status', 'Customer_ID',
#        'Vehicle_Type', 'Pickup_Location', 'Drop_Location', 'V_TAT', 'C_TAT',
#        'Canceled_Rides_by_Customer', 'Canceled_Rides_by_Driver',
#        'Incomplete_Rides', 'Incomplete_Rides_Reason', 'Booking_Value',
#        'Payment_Method', 'Ride_Distance', 'Driver_Ratings', 'Customer_Rating',
#        'Vehicle Images'],
#       dtype='str')

# %%
Step 10: checking if there are any duplicate values in dataset, here we can see there are no duplicate values.

# %%
print(js.duplicated().sum())
# Out:
# 0

# %%
Outlier detection.

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_excel("OLA_dataset.xlsx", sheet_name="July")

target_columns = ["Booking_Value", "Ride_Distance", "Driver_Ratings", "Customer_Rating"]

df.boxplot(column=target_columns)

plt.title("Outlier Overview - All OLA Ride Columns")
plt.ylabel("Values")
plt.xticks(rotation=15) 
plt.tight_layout()
plt.show()

# %%
Here I have not deleted the outliers of the booking value column because we dont know if the outlier is entered by human error is a an actual true correct value entered. In a ride business, extreme numbers are often real business events, not system errors.

# %%
Checking correlation.

# %%
import pandas as pd

df = pd.read_excel("OLA_dataset.xlsx", sheet_name="July")


corr_matrix = df.corr(numeric_only=True)


print(corr_matrix)
# Out:
#                     V_TAT     C_TAT  Booking_Value  Ride_Distance  \
# V_TAT            1.000000  0.000249      -0.003671      -0.011204
# C_TAT            0.000249  1.000000      -0.004443       0.000074
# Booking_Value   -0.003671 -0.004443       1.000000       0.000492
# Ride_Distance   -0.011204  0.000074       0.000492       1.000000
# Driver_Ratings  -0.002300 -0.002815      -0.001327      -0.007235
# Customer_Rating  0.000574  0.001015       0.006231       0.009871
# Vehicle Images        NaN       NaN            NaN            NaN
#
#                  Driver_Ratings  Customer_Rating  Vehicle Images
# V_TAT                 -0.002300         0.000574             NaN
# C_TAT                 -0.002815         0.001015             NaN
# Booking_Value         -0.001327         0.006231             NaN
# Ride_Distance         -0.007235         0.009871             NaN
# Driver_Ratings         1.000000        -0.002807             NaN
# ...

# %%
Plotting the heatmap for correlation check.

# %%
import sys
# !{sys.executable} -m pip install seaborn pandas openpyxl matplotlib
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# WARNING: Cache entry deserialization failed, entry ignored
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel("OLA_dataset.xlsx", sheet_name="July")


corr_matrix = df.corr(numeric_only=True)


plt.figure(figsize=(10, 8))


sns.heatmap(
    corr_matrix, 
    annot=True,          
    cmap='coolwarm',     
    fmt=".2f",           
    vmin=-1, vmax=1,     
    linewidths=0.5       
)


plt.title('Correlation Matrix - July OLA Dataset', fontsize=14, pad=15)
plt.xticks(rotation=45, ha='right') 
plt.tight_layout()                 
plt.show()

# %%
Step 11: checking to see if we need to standardize the formats of the data inside the colums,
here there is no need to standardize the data formats because all the data inside the colums is in a uniform range.

# %%
1st query: Retrieve all successful bookings

# %%
# %pip install duckdb openpyxl pandas

import duckdb
import pandas as pd

conn = duckdb.connect(database=":memory:")

conn.execute("INSTALL spatial;")
conn.execute("LOAD spatial;")

excel_file = r"C:/Users/pc/Desktop/miniproject2/OLA_dataset.xlsx"

df = pd.read_excel(excel_file)

sql_query = "SELECT * FROM df WHERE Booking_Status = 'Success';"

df_successful_bookings = conn.execute(sql_query).df()

df_successful_bookings
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#                      Date      Time     Booking_ID Booking_Status Customer_ID  \
# 0     2024-07-25 22:20:00  22:20:00  CNR2940424040        Success   CID225428
# 1     2024-07-30 19:59:00  19:59:00  CNR2982357879        Success   CID270156
# 2     2024-07-02 09:02:00  09:02:00  CNR1797421769        Success   CID939555
# 3     2024-07-13 04:42:00  04:42:00  CNR8787177882        Success   CID802429
# 4     2024-07-23 09:51:00  09:51:00  CNR3612067560        Success   CID476071
# ...                   ...       ...            ...            ...         ...
# 63962 2024-07-31 09:06:00  09:06:00  CNR9488489435        Success   CID371654
# 63963 2024-07-31 15:12:00  15:12:00  CNR3151743100        Success   CID334158
# ...

# %%
2nd query:  Find the average ride distance for each vehicle type.

# %%
# %pip install duckdb openpyxl pandas

import duckdb
import pandas as pd

conn = duckdb.connect(database=":memory:")

conn.execute("INSTALL spatial;")
conn.execute("LOAD spatial;")

excel_file = r"C:/Users/pc/Desktop/miniproject2/OLA_dataset.xlsx"

df = pd.read_excel(excel_file)

sql_query ="SELECT Vehicle_Type, AVG(Ride_Distance) AS Average_Distance FROM df GROUP BY Vehicle_Type ORDER BY Average_Distance DESC;"

df_ride_distance = conn.execute(sql_query).df()

df_ride_distance
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Vehicle_Type  Average_Distance
# 0  Prime Sedan         15.764939
# 1        eBike         15.580589
# 2         Bike         15.533079
# 3         Mini         15.510102
# 4   Prime Plus         15.447474
# 5    Prime SUV         15.274514
# 6         Auto          6.238089

# %%
3rd query:  Get the total number of cancelled rides by customers.

# %%
# %pip install duckdb openpyxl pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import duckdb
import pandas as pd

conn = duckdb.connect(database=":memory:")

conn.execute("INSTALL spatial;")
conn.execute("LOAD spatial;")

excel_file = r"C:/Users/pc/Desktop/miniproject2/OLA_dataset.xlsx"

df = pd.read_excel(excel_file)

sql_query ="SELECT COUNT(*) AS Total_Customer_Cancellations FROM df WHERE Booking_Status = 'Canceled by Customer';"

df_cancelled_rides =  conn.execute(sql_query).df()

df_cancelled_rides
# Out:
#    Total_Customer_Cancellations
# 0                         10499

# %%
4th query: List the top 5 customers who booked the highest number of rides.

# %%
import duckdb
import pandas as pd

conn = duckdb.connect(database=":memory:")

conn.execute("INSTALL spatial;")
conn.execute("LOAD spatial;")

excel_file = r"C:/Users/pc/Desktop/miniproject2/OLA_dataset.xlsx"

df = pd.read_excel(excel_file)

sql_query = " SELECT Customer_ID,  COUNT(*) AS Total_Bookings FROM df GROUP BY Customer_ID ORDER BY Total_Bookings DESC LIMIT 5;"

df_highest_rides = conn.execute(sql_query).df()

df_highest_rides
# Out:
#   Customer_ID  Total_Bookings
# 0   CID954071               5
# 1   CID329193               4
# 2   CID465260               4
# 3   CID782883               4
# 4   CID980727               4

# %%
5th query:Get the number of rides cancelled by drivers due to personal and car-related issues.

# %%
import duckdb
import pandas as pd

conn = duckdb.connect(database=":memory:")

conn.execute("INSTALL spatial;")
conn.execute("LOAD spatial;")

excel_file = r"C:/Users/pc/Desktop/miniproject2/OLA_dataset.xlsx"

df = pd.read_excel(excel_file)

sql_query ="SELECT COUNT(*) AS Driver_Issue_Cancellations FROM df WHERE Canceled_Rides_by_Driver = 'Personal & Car related issue'";

df_rides_cancelled = conn.execute(sql_query).df()

df_rides_cancelled
# Out:
#    Driver_Issue_Cancellations
# 0                        6542

# %%
6th query: Find the maximum and minimum driver ratings for Prime Sedan bookings.

# %%
import duckdb
import pandas as pd

conn = duckdb.connect(database=":memory:")

conn.execute("INSTALL spatial;")
conn.execute("LOAD spatial;")

excel_file = r"C:/Users/pc/Desktop/miniproject2/OLA_dataset.xlsx"

df = pd.read_excel(excel_file)

sql_query =" SELECT MAX(Driver_Ratings) AS Maximum_Rating, MIN(Driver_Ratings) AS Minimum_Rating FROM df WHERE Vehicle_Type = 'Prime Sedan';"

df_driver_ratings = conn.execute(sql_query).df()

df_driver_ratings
# Out:
#    Maximum_Rating  Minimum_Rating
# 0             5.0             3.0

# %%
7th query: Retrieve all rides where payment was made using UPI.

# %%
import duckdb
import pandas as pd

conn = duckdb.connect(database=":memory:")

conn.execute("INSTALL spatial;")
conn.execute("LOAD spatial;")

excel_file = r"C:/Users/pc/Desktop/miniproject2/OLA_dataset.xlsx"

df = pd.read_excel(excel_file)

sql_query ="SELECT * FROM df WHERE Payment_Method = 'UPI';"

df_upi_rides = conn.execute(sql_query).df()

df_upi_rides
# Out:
#                      Date      Time     Booking_ID Booking_Status Customer_ID  \
# 0     2024-07-30 19:59:00  19:59:00  CNR2982357879        Success   CID270156
# 1     2024-07-13 04:42:00  04:42:00  CNR8787177882        Success   CID802429
# 2     2024-07-27 13:18:00  13:18:00  CNR4524472111        Success   CID540929
# 3     2024-07-16 09:54:00  09:54:00  CNR8181602032        Success   CID167642
# 4     2024-07-02 10:25:00  10:25:00  CNR8090918544        Success   CID640151
# ...                   ...       ...            ...            ...         ...
# 25876 2024-07-31 19:34:00  19:34:00  CNR4870774895        Success   CID266336
# 25877 2024-07-31 03:00:00  03:00:00  CNR9738039746        Success   CID922711
# 25878 2024-07-31 15:12:00  15:12:00  CNR3151743100        Success   CID334158
# 25879 2024-07-31 14:56:00  14:56:00  CNR2027162035        Success   CID118301
# 25880 2024-07-31 13:57:00  13:57:00  CNR9770709721        Success   CID217959
#
# ...

# %%
8th query: Find the average customer rating per vehicle type.

# %%
import duckdb
import pandas as pd

conn = duckdb.connect(database=":memory:")

conn.execute("INSTALL spatial;")
conn.execute("LOAD spatial;")

excel_file = r"C:/Users/pc/Desktop/miniproject2/OLA_dataset.xlsx"

df = pd.read_excel(excel_file)

sql_query =" SELECT Vehicle_Type,  ROUND(AVG(Customer_Rating), 2) AS Average_Customer_Rating FROM df WHERE Customer_Rating IS NOT NULL GROUP BY Vehicle_Type ORDER BY Average_Customer_Rating DESC;"

df_avg_customer_rating = conn.execute(sql_query).df()

df_avg_customer_rating
# Out:
#   Vehicle_Type  Average_Customer_Rating
# 0   Prime Plus                     4.01
# 1  Prime Sedan                     4.00
# 2         Auto                     4.00
# 3    Prime SUV                     4.00
# 4         Mini                     4.00
# 5         Bike                     3.99
# 6        eBike                     3.99

# %%
9th query: Calculate the total booking value of rides completed successfully.

# %%
import duckdb
import pandas as pd

conn = duckdb.connect(database=":memory:")

conn.execute("INSTALL spatial;")
conn.execute("LOAD spatial;")

excel_file = r"C:/Users/pc/Desktop/miniproject2/OLA_dataset.xlsx"

df = pd.read_excel(excel_file)

sql_query = "SELECT  SUM(Booking_Value) AS Total_Successful_Revenue FROM df WHERE Booking_Status = 'Success';"

df_total_booking_value = conn.execute(sql_query).df()

df_total_booking_value
# Out:
#    Total_Successful_Revenue
# 0                35080467.0

# %%
10th query: List all incomplete rides along with the reason.

# %%
import duckdb
import pandas as pd

conn = duckdb.connect(database=":memory:")

conn.execute("INSTALL spatial;")
conn.execute("LOAD spatial;")

excel_file = r"C:/Users/pc/Desktop/miniproject2/OLA_dataset.xlsx"

df = pd.read_excel(excel_file)

sql_query ="SELECT Booking_ID,  Incomplete_Rides, Incomplete_Rides_Reason FROM df WHERE Incomplete_Rides = 'Yes' OR Incomplete_Rides_Reason IS NOT NULL;"

df_incomplete_rides = conn.execute(sql_query).df()

df_incomplete_rides
# Out:
#          Booking_ID Incomplete_Rides Incomplete_Rides_Reason
# 0     CNR5176704322              Yes         Customer Demand
# 1     CNR9312632867              Yes       Vehicle Breakdown
# 2     CNR7924302885              Yes         Customer Demand
# 3     CNR1640228587              Yes             Other Issue
# 4     CNR7623690602              Yes             Other Issue
# ...             ...              ...                     ...
# 3921  CNR5546265534              Yes         Customer Demand
# 3922  CNR1954831907              Yes       Vehicle Breakdown
# 3923  CNR1271821250              Yes       Vehicle Breakdown
# 3924  CNR4652634649              Yes       Vehicle Breakdown
# 3925  CNR5427755403              Yes             Other Issue
#
# [3926 rows x 3 columns]
